# %% [markdown]
# ## Data Wrangling for Zillow Rental/House prices

# %%
#Import libraries that will be used:

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Pull in the csv files from the download folder
#median rent
df_median_rent = pd.read_csv('../data/raw/City_MedianRentalPrice_AllHomes.csv')

# %%
#Median house price
df_median_home = pd.read_csv('../data/raw/City_Zhvi_AllHomes.csv')

# %% [markdown]
# ## Data Defining - gaining understanding of data features to inform the next steps

# %%
#get head to see column names
df_median_rent.head()
# Out:
#    Unnamed: 0   RegionName State                             Metro  \
# 0           0     New York    NY       New York-Newark-Jersey City
# 1           1  Los Angeles    CA    Los Angeles-Long Beach-Anaheim
# 2           2      Houston    TX  Houston-The Woodlands-Sugar Land
# 3           3      Chicago    IL          Chicago-Naperville-Elgin
# 4           4  San Antonio    TX         San Antonio-New Braunfels
#
#            CountyName  SizeRank  2010-01  2010-02  2010-03  2010-04  ...  \
# 0       Queens County         1      NaN      NaN      NaN      NaN  ...
# 1  Los Angeles County         2      NaN      NaN      NaN      NaN  ...
# 2       Harris County         3      NaN      NaN      NaN      NaN  ...
# 3         Cook County         4      NaN   1600.0   1500.0   1500.0  ...
# 4        Bexar County         5      NaN      NaN      NaN      NaN  ...
#
#    2019-03  2019-04  2019-05  2019-06  2019-07  2019-08  2019-09  2019-10  \
# ...

# %%
#looking at data types
df_median_home.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27330 entries, 0 to 27329
# Columns: 300 entries, Unnamed: 0 to 2020-03-31
# dtypes: float64(291), int64(3), object(6)
# memory usage: 62.6+ MB

# %%
# We see that we have 1699 rows, 126 columns, of that 120 are floats, 2 are int's, and 4 are objects.

# %%
#get head to see column names
df_median_rent.head()
# Out:
#    Unnamed: 0   RegionName State                             Metro  \
# 0           0     New York    NY       New York-Newark-Jersey City
# 1           1  Los Angeles    CA    Los Angeles-Long Beach-Anaheim
# 2           2      Houston    TX  Houston-The Woodlands-Sugar Land
# 3           3      Chicago    IL          Chicago-Naperville-Elgin
# 4           4  San Antonio    TX         San Antonio-New Braunfels
#
#            CountyName  SizeRank  2010-01  2010-02  2010-03  2010-04  ...  \
# 0       Queens County         1      NaN      NaN      NaN      NaN  ...
# 1  Los Angeles County         2      NaN      NaN      NaN      NaN  ...
# 2       Harris County         3      NaN      NaN      NaN      NaN  ...
# 3         Cook County         4      NaN   1600.0   1500.0   1500.0  ...
# 4        Bexar County         5      NaN      NaN      NaN      NaN  ...
#
#    2019-03  2019-04  2019-05  2019-06  2019-07  2019-08  2019-09  2019-10  \
# ...

# %%
#looking at data types
df_median_home.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27330 entries, 0 to 27329
# Columns: 300 entries, Unnamed: 0 to 2020-03-31
# dtypes: float64(291), int64(3), object(6)
# memory usage: 62.6+ MB

# %%
# We see that we have 27,330 rows of data and 300 columns.  291 are floats, 3 are int's and 6 are objects.

# %%
#Get summary stats for both dataframes
df_median_home.describe()
# Out:
#          Unnamed: 0       RegionID      SizeRank    1996-01-31    1996-02-29  \
# count  27330.000000   27330.000000  27330.000000  1.061700e+04  1.082300e+04
# mean   13664.500000   65503.787413  14746.725027  1.219672e+05  1.216621e+05
# std     7889.635765  103118.832955   8791.175746  9.203687e+04  9.170803e+04
# min        0.000000    3299.000000      0.000000  1.192900e+04  1.184000e+04
# 25%     6832.250000   18398.000000   7112.250000  6.852900e+04  6.844600e+04
# 50%    13664.500000   33660.500000  14453.000000  1.014940e+05  1.013100e+05
# 75%    20496.750000   49422.750000  22301.000000  1.492710e+05  1.487455e+05
# max    27329.000000  760887.000000  29449.000000  1.764961e+06  1.765793e+06
#
#          1996-03-31    1996-04-30    1996-05-31    1996-06-30    1996-07-31  \
# count  1.086400e+04  1.088600e+04  1.096600e+04  1.099600e+04  1.102700e+04
# mean   1.215214e+05  1.215839e+05  1.217755e+05  1.218581e+05  1.220267e+05
# ...

# %%
df_median_rent.describe()
# Out:
#        Unnamed: 0     SizeRank  2010-01      2010-02      2010-03  \
# count  1699.00000  1699.000000      1.0    30.000000    62.000000
# mean    849.00000   849.992348    895.0  1408.433333  1343.040323
# std     490.60337   490.601169      NaN   444.181264   395.872934
# min       0.00000     1.000000    895.0   795.000000   737.500000
# 25%     424.50000   425.000000    895.0  1112.500000  1058.750000
# 50%     849.00000   850.000000    895.0  1300.000000  1250.000000
# 75%    1273.50000  1274.500000    895.0  1600.000000  1500.000000
# max    1698.00000  1699.000000    895.0  2400.000000  2500.000000
#
#            2010-04      2010-05      2010-06      2010-07      2010-08  ...  \
# count    80.000000    83.000000    84.000000    90.000000    99.000000  ...
# mean   1408.325000  1420.361446  1446.375000  1481.850000  1547.792929  ...
# std     473.968741   479.819442   507.469388   547.253574   663.246884  ...
# ...

# %%
#Check for missing data

#Count with .sum() the number of missing values .isnull() in each column of 
#home_prices as well as the percentages .mean() instead of .sum()
#Order them using sort_values
#Call pd.concat to present these in a separate df with column names 'count' and '%'
missing_df_rent = pd.concat([df_median_rent.isnull().sum(), 100 * df_median_rent.isnull().mean()], axis=1)
missing_df_rent.columns=['count', '%']
missing_df_rent.sort_values(by='count', ascending=False)
# Out:
#             count          %
# 2010-01      1698  99.941142
# 2010-02      1669  98.234255
# 2010-03      1637  96.350795
# 2010-04      1619  95.291348
# 2010-05      1616  95.114773
# ...           ...        ...
# RegionName      0   0.000000
# SizeRank        0   0.000000
# CountyName      0   0.000000
# State           0   0.000000
# 2019-12         0   0.000000
#
# [126 rows x 2 columns]

# %%
#Check for missing data in other data frame

#Count with .sum() the number of missing values .isnull() in each column of 
#home_prices as well as the percentages .mean() instead of .sum()
#Order them using sort_values
#Call pd.concat to present these in a separate df with column names 'count' and '%'
missing_df_home = pd.concat([df_median_home.isnull().sum(), 100 * df_median_home.isnull().mean()], axis=1)
missing_df_home.columns=['count', '%']
missing_df_home.sort_values(by='count', ascending=False)
# Out:
#             count          %
# 1996-01-31  16713  61.152580
# 1996-02-29  16507  60.398829
# 1996-03-31  16466  60.248811
# 1996-04-30  16444  60.168313
# 1996-05-31  16364  59.875595
# ...           ...        ...
# 2018-05-31      0   0.000000
# 2018-06-30      0   0.000000
# 2018-07-31      0   0.000000
# 2018-08-31      0   0.000000
# 2020-03-31      0   0.000000
#
# [300 rows x 2 columns]

# %% [markdown]
# There will be some data that needs to be dropped since there are lots of missing values

# %%
#Going local, lets get the median home price of Denver County and create new DF

df_denver_county_home = df_median_home[df_median_home.CountyName == 'Denver County']

# %%
#get .head for this df
df_denver_county_home.head()
# Out:
#     Unnamed: 0  RegionID  SizeRank RegionName RegionType StateName State  \
# 23          23     11093        23     Denver       City        CO    CO
#
#                      Metro     CountyName  1996-01-31  ...  2019-06-30  \
# 23  Denver-Aurora-Lakewood  Denver County    126922.0  ...    454558.0
#
#     2019-07-31  2019-08-31  2019-09-30  2019-10-31  2019-11-30  2019-12-31  \
# 23    454578.0    455615.0    456193.0    456663.0    457096.0    458434.0
#
#     2020-01-31  2020-02-29  2020-03-31
# 23    460255.0    462640.0    465466.0
#
# [1 rows x 300 columns]

# %%
#Let's also get the median rent price of denver county and create a new DF

df_denver_county_rent = df_median_rent[df_median_rent.CountyName == 'Denver County']

# %%
# get .head for rent df
df_denver_county_rent.head()
# Out:
#     Unnamed: 0 RegionName State                   Metro     CountyName  \
# 23          23     Denver    CO  Denver-Aurora-Lakewood  Denver County
#
#     SizeRank  2010-01  2010-02  2010-03  2010-04  ...  2019-03  2019-04  \
# 23        24      NaN      NaN      NaN      NaN  ...   2150.0   2200.0
#
#     2019-05  2019-06  2019-07  2019-08  2019-09  2019-10  2019-11  2019-12
# 23   2200.0   2200.0   2200.0   2195.0   2200.0   2200.0   2150.0   2150.0
#
# [1 rows x 126 columns]

# %%
rent_columns = list(df_denver_county_rent)
for i in rent_columns:
 
    # printing element
    print (df_denver_county_rent[i])
# Out:
# 23    23
# Name: Unnamed: 0, dtype: int64
# 23    Denver
# Name: RegionName, dtype: object
# 23    CO
# Name: State, dtype: object
# 23    Denver-Aurora-Lakewood
# Name: Metro, dtype: object
# 23    Denver County
# Name: CountyName, dtype: object
# 23    24
# Name: SizeRank, dtype: int64
# 23   NaN
# Name: 2010-01, dtype: float64
# 23   NaN
# Name: 2010-02, dtype: float64
# 23   NaN
# Name: 2010-03, dtype: float64
# 23   NaN
# Name: 2010-04, dtype: float64
# 23   NaN
# Name: 2010-05, dtype: float64
# 23   NaN
# Name: 2010-06, dtype: float64
# 23   NaN
# Name: 2010-07, dtype: float64
# 23   NaN
# Name: 2010-08, dtype: float64
# 23   NaN
# Name: 2010-09, dtype: float64
# 23    1100.0
# Name: 2010-10, dtype: float64
# 23    1275.0
# Name: 2010-11, dtype: float64
# 23    1275.0
# Name: 2010-12, dtype: float64
# 23    1300.0
# Name: 2011-01, dtype: float64
# 23    1350.0
# Name: 2011-02, dtype: float64
# 23    1400.0
# Name: 2011-03, dtype: float64
# 23    1350.0
# ...

# %%
home_columns = list(df_denver_county_home)
for i in home_columns:
 
    # printing element
    print (df_denver_county_home[i])
# Out:
# 23    23
# Name: Unnamed: 0, dtype: int64
# 23    11093
# Name: RegionID, dtype: int64
# 23    23
# Name: SizeRank, dtype: int64
# 23    Denver
# Name: RegionName, dtype: object
# 23    City
# Name: RegionType, dtype: object
# 23    CO
# Name: StateName, dtype: object
# 23    CO
# Name: State, dtype: object
# 23    Denver-Aurora-Lakewood
# Name: Metro, dtype: object
# 23    Denver County
# Name: CountyName, dtype: object
# 23    126922.0
# Name: 1996-01-31, dtype: float64
# 23    127499.0
# Name: 1996-02-29, dtype: float64
# 23    127991.0
# Name: 1996-03-31, dtype: float64
# 23    129031.0
# Name: 1996-04-30, dtype: float64
# 23    129940.0
# Name: 1996-05-31, dtype: float64
# 23    130819.0
# Name: 1996-06-30, dtype: float64
# 23    131687.0
# Name: 1996-07-31, dtype: float64
# 23    132391.0
# Name: 1996-08-31, dtype: float64
# 23    133220.0
# Name: 1996-09-30, dtype: float64
# 23    133969.0
# Name: 1996-10-31, dtype: float64
# 23    135093.0
# Name: 1996-11-30, dtype: float64
# ...

# %%
#single out the rental price in Dec of 2019
dec_den_rent = df_denver_county_rent['2019-12'][23]

# %%
#single out the home price in Dec of 2019
dec_den_home = df_denver_county_home['2019-12-31'][23]

# %%
#Median rent for Denver in December of 2019
print(dec_den_rent)
# Out:
# 2150.0

# %%
#Median home price for Denver in December of 2019
print(dec_den_home)
# Out:
# 458434.0

# %%
dec_ratio = dec_den_rent / dec_den_home

# %%
print(dec_ratio)
# Out:
# 0.004689879022934599

# %% [markdown]
# If I'm going to compare a ratio for home prices to rent prices, it would appear that the
# last month of data I have for rent is December of 2019.  The house price data has info up to end March 2020.  This isn't necessarily a bad thing if I plot the data and have house price extend farther than rent price.

# %%
#establish uniqueness based on state and county pairing.

df_median_rent['state_county_for_joining'] = df_median_rent['State'] + ' ' + df_median_rent['CountyName']

# %%
df_median_home['state_county_for_joining'] = df_median_home['State'] + ' ' + df_median_home['CountyName']

# %%
df_median_home.head()
# Out:
#    Unnamed: 0  RegionID  SizeRank   RegionName RegionType StateName State  \
# 0           0      6181         0     New York       City        NY    NY
# 1           1     12447         1  Los Angeles       City        CA    CA
# 2           2     39051         2      Houston       City        TX    TX
# 3           3     17426         3      Chicago       City        IL    IL
# 4           4      6915         4  San Antonio       City        TX    TX
#
#                               Metro          CountyName  1996-01-31  ...  \
# 0       New York-Newark-Jersey City       Queens County    196258.0  ...
# 1    Los Angeles-Long Beach-Anaheim  Los Angeles County    185649.0  ...
# 2  Houston-The Woodlands-Sugar Land       Harris County     93518.0  ...
# 3          Chicago-Naperville-Elgin         Cook County    130920.0  ...
# 4         San Antonio-New Braunfels        Bexar County     94041.0  ...
#
#    2019-07-31  2019-08-31  2019-09-30  2019-10-31  2019-11-30  2019-12-31  \
# ...

# %%
df_median_rent.head()
# Out:
#    Unnamed: 0   RegionName State                             Metro  \
# 0           0     New York    NY       New York-Newark-Jersey City
# 1           1  Los Angeles    CA    Los Angeles-Long Beach-Anaheim
# 2           2      Houston    TX  Houston-The Woodlands-Sugar Land
# 3           3      Chicago    IL          Chicago-Naperville-Elgin
# 4           4  San Antonio    TX         San Antonio-New Braunfels
#
#            CountyName  SizeRank  2010-01  2010-02  2010-03  2010-04  ...  \
# 0       Queens County         1      NaN      NaN      NaN      NaN  ...
# 1  Los Angeles County         2      NaN      NaN      NaN      NaN  ...
# 2       Harris County         3      NaN      NaN      NaN      NaN  ...
# 3         Cook County         4      NaN   1600.0   1500.0   1500.0  ...
# 4        Bexar County         5      NaN      NaN      NaN      NaN  ...
#
#    2019-04  2019-05  2019-06  2019-07  2019-08  2019-09  2019-10  2019-11  \
# ...

# %%
#lets drop some columns
#where 1 is the axis number (0 for rows and 1 for columns.)

df_median_rent_dropped = df_median_rent.drop('2010-01', axis=1)

# %%
#check to make sure it dropped
df_median_rent_dropped.head()
# Out:
#    Unnamed: 0   RegionName State                             Metro  \
# 0           0     New York    NY       New York-Newark-Jersey City
# 1           1  Los Angeles    CA    Los Angeles-Long Beach-Anaheim
# 2           2      Houston    TX  Houston-The Woodlands-Sugar Land
# 3           3      Chicago    IL          Chicago-Naperville-Elgin
# 4           4  San Antonio    TX         San Antonio-New Braunfels
#
#            CountyName  SizeRank  2010-02  2010-03  2010-04  2010-05  ...  \
# 0       Queens County         1      NaN      NaN      NaN   2300.0  ...
# 1  Los Angeles County         2      NaN      NaN      NaN      NaN  ...
# 2       Harris County         3      NaN      NaN      NaN      NaN  ...
# 3         Cook County         4   1600.0   1500.0   1500.0   1500.0  ...
# 4        Bexar County         5      NaN      NaN      NaN      NaN  ...
#
#    2019-04  2019-05  2019-06  2019-07  2019-08  2019-09  2019-10  2019-11  \
# ...

# %%
#drop some more columns

df_median_rent_dropped = df_median_rent.drop(['2010-01', '2010-02', '2010-03', '2010-04',
                                             '2010-05', '2010-06', '2010-07', '2010-08',
                                             '2010-09', '2010-10', '2010-11', '2010-12',
                                             '2011-01', '2011-02', '2011-03', '2011-04',
                                             '2011-05', '2011-06', '2011-07', '2011-08',
                                             '2011-09', '2011-10', '2011-11', '2011-12'], axis=1)

# %%
df_median_rent_dropped.head()
# Out:
#    Unnamed: 0   RegionName State                             Metro  \
# 0           0     New York    NY       New York-Newark-Jersey City
# 1           1  Los Angeles    CA    Los Angeles-Long Beach-Anaheim
# 2           2      Houston    TX  Houston-The Woodlands-Sugar Land
# 3           3      Chicago    IL          Chicago-Naperville-Elgin
# 4           4  San Antonio    TX         San Antonio-New Braunfels
#
#            CountyName  SizeRank  2012-01  2012-02  2012-03  2012-04  ...  \
# 0       Queens County         1   2450.0   2600.0   2550.0   2595.0  ...
# 1  Los Angeles County         2      NaN      NaN      NaN      NaN  ...
# 2       Harris County         3      NaN      NaN      NaN      NaN  ...
# 3         Cook County         4   1625.0   1635.0   1650.0   1600.0  ...
# 4        Bexar County         5   1150.0   1150.0   1150.0   1050.0  ...
#
#    2019-04  2019-05  2019-06  2019-07  2019-08  2019-09  2019-10  2019-11  \
# ...

# %%
missing_df_rent = pd.concat([df_median_rent_dropped.isnull().sum(), 100 * df_median_rent_dropped.isnull().mean()], axis=1)
missing_df_rent.columns=['count', '%']
missing_df_rent.sort_values(by='count', ascending=True)
# Out:
#             count          %
# Unnamed: 0      0   0.000000
# 2019-11         0   0.000000
# 2019-10         0   0.000000
# 2019-09         0   0.000000
# 2019-08         0   0.000000
# ...           ...        ...
# 2012-05      1070  62.978222
# 2012-04      1076  63.331371
# 2012-03      1088  64.037669
# 2012-02      1098  64.626251
# 2012-01      1104  64.979400
#
# [103 rows x 2 columns]

# %%
#count unique values in 2019-12

print(len(df_median_rent_dropped['2019-11'].unique()))
# Out:
# 432

# %%
print(len(df_median_rent_dropped['2019-12'].unique()))
# Out:
# 427

# %%
print(len(df_median_home['2019-11-30'].unique()))
# Out:
# 26198

# %%
print(len(df_median_home['2019-12-31'].unique()))
# Out:
# 26222

# %%
#rent_2019 = df_median_rent_dropped.iloc['2900']
