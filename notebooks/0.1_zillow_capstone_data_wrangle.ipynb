# %% [markdown]
# # Capstone project 1 - Data Wrangling
# In this section, I will attempt to wrangle Zillow housing data.  Starting off, I'll import libraries.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
city_median_rent_all_homes = pd.read_csv('../Zillow_housing_data_capstone1/City_MedianRentalPrice_AllHomes.csv')

# %% [markdown]
# City_median file looks to be the median rental price of houses in a region.

# %%
city_median_rent_all_homes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1699 entries, 0 to 1698
# Columns: 126 entries, Unnamed: 0 to 2019-12
# dtypes: float64(120), int64(2), object(4)
# memory usage: 1.6+ MB

# %%
city_median_rent_all_homes.describe()
# Out:
#        Unnamed: 0     SizeRank  2010-01      2010-02      2010-03  \
# count  1699.00000  1699.000000      1.0    30.000000    62.000000
# mean    849.00000   849.992348    895.0  1408.433333  1343.040323
# std     490.60337   490.601169      NaN   444.181264   395.872934
# min       0.00000     1.000000    895.0   795.000000   737.500000
# 25%     424.50000   425.000000    895.0  1112.500000  1058.750000
# 50%     849.00000   850.000000    895.0  1300.000000  1250.000000
# 75%    1273.50000  1274.500000    895.0  1600.000000  1500.000000
# max    1698.00000  1699.000000    895.0  2400.000000  2500.000000
#
#            2010-04      2010-05      2010-06      2010-07      2010-08  ...  \
# count    80.000000    83.000000    84.000000    90.000000    99.000000  ...
# mean   1408.325000  1420.361446  1446.375000  1481.850000  1547.792929  ...
# std     473.968741   479.819442   507.469388   547.253574   663.246884  ...
# ...

# %%
city_median_rent_all_homes.head()
# Out:
#    Unnamed: 0   RegionName State                             Metro  \
# 0           0     New York    NY       New York-Newark-Jersey City
# 1           1  Los Angeles    CA    Los Angeles-Long Beach-Anaheim
# 2           2      Houston    TX  Houston-The Woodlands-Sugar Land
# 3           3      Chicago    IL          Chicago-Naperville-Elgin
# 4           4  San Antonio    TX         San Antonio-New Braunfels
#
#            CountyName  SizeRank  2010-01  2010-02  2010-03  2010-04  ...  \
# 0       Queens County         1      NaN      NaN      NaN      NaN  ...
# 1  Los Angeles County         2      NaN      NaN      NaN      NaN  ...
# 2       Harris County         3      NaN      NaN      NaN      NaN  ...
# 3         Cook County         4      NaN   1600.0   1500.0   1500.0  ...
# 4        Bexar County         5      NaN      NaN      NaN      NaN  ...
#
#    2019-03  2019-04  2019-05  2019-06  2019-07  2019-08  2019-09  2019-10  \
# ...

# %%
city_median_rent_all_homes[city_median_rent_all_homes.State == 'CO']
# Out:
#       Unnamed: 0          RegionName State                   Metro  \
# 23            23              Denver    CO  Denver-Aurora-Lakewood
# 42            42    Colorado Springs    CO        Colorado Springs
# 56            56              Aurora    CO  Denver-Aurora-Lakewood
# 151          151        Fort Collins    CO            Fort Collins
# 197          197              Pueblo    CO                  Pueblo
# 203          203            Lakewood    CO  Denver-Aurora-Lakewood
# 249          249            Thornton    CO  Denver-Aurora-Lakewood
# 255          255             Boulder    CO                 Boulder
# 291          291         Westminster    CO  Denver-Aurora-Lakewood
# 299          299              Arvada    CO  Denver-Aurora-Lakewood
# 345          345          Centennial    CO  Denver-Aurora-Lakewood
# 363          363      Grand Junction    CO          Grand Junction
# 386          386     Highlands Ranch    CO  Denver-Aurora-Lakewood
# ...

# %% [markdown]
# This is the median rental price of homes in colorado.  There seems to be lots of NaN's in the first few months of data.

# %%
home_prices_all = pd.read_csv('../Zillow_housing_data_capstone1/City_Zhvi_AllHomes.csv')

# %%
#Median rent for Denver County
city_median_rent_all_homes[city_median_rent_all_homes.CountyName == 'Denver County']
# Out:
#     Unnamed: 0 RegionName State                   Metro     CountyName  \
# 23          23     Denver    CO  Denver-Aurora-Lakewood  Denver County
#
#     SizeRank  2010-01  2010-02  2010-03  2010-04  ...  2019-03  2019-04  \
# 23        24      NaN      NaN      NaN      NaN  ...   2150.0   2200.0
#
#     2019-05  2019-06  2019-07  2019-08  2019-09  2019-10  2019-11  2019-12
# 23   2200.0   2200.0   2200.0   2195.0   2200.0   2200.0   2150.0   2150.0
#
# [1 rows x 126 columns]

# %%
#Median home price Denver County
denver_county_prices = home_prices_all[home_prices_all.CountyName == 'Denver County']

# %%
denver_county_prices.head()
# Out:
#     Unnamed: 0  RegionID  SizeRank RegionName RegionType StateName State  \
# 23          23     11093        23     Denver       City        CO    CO
#
#                      Metro     CountyName  1996-01-31  ...  2019-06-30  \
# 23  Denver-Aurora-Lakewood  Denver County    126922.0  ...    454558.0
#
#     2019-07-31  2019-08-31  2019-09-30  2019-10-31  2019-11-30  2019-12-31  \
# 23    454578.0    455615.0    456193.0    456663.0    457096.0    458434.0
#
#     2020-01-31  2020-02-29  2020-03-31
# 23    460255.0    462640.0    465466.0
#
# [1 rows x 300 columns]

# %%
denver_county_prices.info(verbose = True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1 entries, 23 to 23
# Data columns (total 300 columns):
#  #    Column      Dtype
# ---   ------      -----
#  0    Unnamed: 0  int64
#  1    RegionID    int64
#  2    SizeRank    int64
#  3    RegionName  object
#  4    RegionType  object
#  5    StateName   object
#  6    State       object
#  7    Metro       object
#  8    CountyName  object
#  9    1996-01-31  float64
#  10   1996-02-29  float64
#  11   1996-03-31  float64
#  12   1996-04-30  float64
#  13   1996-05-31  float64
#  14   1996-06-30  float64
#  15   1996-07-31  float64
#  16   1996-08-31  float64
#  17   1996-09-30  float64
#  18   1996-10-31  float64
#  19   1996-11-30  float64
#  20   1996-12-31  float64
#  21   1997-01-31  float64
#  22   1997-02-28  float64
#  23   1997-03-31  float64
#  24   1997-04-30  float64
#  25   1997-05-31  float64
#  26   1997-06-30  float64
#  27   1997-07-31  float64
#  28   1997-08-31  float64
#  29   1997-09-30  float64
# ...

# %%
print(denver_county_prices)
# Out:
#     Unnamed: 0  RegionID  SizeRank RegionName RegionType StateName State  \
# 23          23     11093        23     Denver       City        CO    CO
#
#                      Metro     CountyName  1996-01-31  ...  2019-06-30  \
# 23  Denver-Aurora-Lakewood  Denver County    126922.0  ...    454558.0
#
#     2019-07-31  2019-08-31  2019-09-30  2019-10-31  2019-11-30  2019-12-31  \
# 23    454578.0    455615.0    456193.0    456663.0    457096.0    458434.0
#
#     2020-01-31  2020-02-29  2020-03-31
# 23    460255.0    462640.0    465466.0
#
# [1 rows x 300 columns]

# %%
denver_county_prices.hist()
# Out:
# array([[<AxesSubplot:title={'center':'Unnamed: 0'}>,
#         <AxesSubplot:title={'center':'RegionID'}>,
#         <AxesSubplot:title={'center':'SizeRank'}>,
#         <AxesSubplot:title={'center':'1996-01-31'}>,
#         <AxesSubplot:title={'center':'1996-02-29'}>,
#         <AxesSubplot:title={'center':'1996-03-31'}>,
#         <AxesSubplot:title={'center':'1996-04-30'}>,
#         <AxesSubplot:title={'center':'1996-05-31'}>,
#         <AxesSubplot:title={'center':'1996-06-30'}>,
#         <AxesSubplot:title={'center':'1996-07-31'}>,
#         <AxesSubplot:title={'center':'1996-08-31'}>,
#         <AxesSubplot:title={'center':'1996-09-30'}>,
#         <AxesSubplot:title={'center':'1996-10-31'}>,
#         <AxesSubplot:title={'center':'1996-11-30'}>,
#         <AxesSubplot:title={'center':'1996-12-31'}>,
#         <AxesSubplot:title={'center':'1997-01-31'}>,
#         <AxesSubplot:title={'center':'1997-02-28'}>],
#        [<AxesSubplot:title={'center':'1997-03-31'}>,
# ...

# %%
sns.histplot(data=denver_county_prices)
# Out:
# <AxesSubplot:ylabel='Count'>

# %%
len(home_prices_all['2020-03-31'].unique())
# Out:
# 26241

# %%
len(city_median_rent_all_homes['2019-12'].unique())
# Out:
# 427

# %% [markdown]
# This file is house sale prices by region

# %%
home_prices_all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27330 entries, 0 to 27329
# Columns: 300 entries, Unnamed: 0 to 2020-03-31
# dtypes: float64(291), int64(3), object(6)
# memory usage: 62.6+ MB

# %%
home_prices_all.describe()
# Out:
#          Unnamed: 0       RegionID      SizeRank    1996-01-31    1996-02-29  \
# count  27330.000000   27330.000000  27330.000000  1.061700e+04  1.082300e+04
# mean   13664.500000   65503.787413  14746.725027  1.219672e+05  1.216621e+05
# std     7889.635765  103118.832955   8791.175746  9.203687e+04  9.170803e+04
# min        0.000000    3299.000000      0.000000  1.192900e+04  1.184000e+04
# 25%     6832.250000   18398.000000   7112.250000  6.852900e+04  6.844600e+04
# 50%    13664.500000   33660.500000  14453.000000  1.014940e+05  1.013100e+05
# 75%    20496.750000   49422.750000  22301.000000  1.492710e+05  1.487455e+05
# max    27329.000000  760887.000000  29449.000000  1.764961e+06  1.765793e+06
#
#          1996-03-31    1996-04-30    1996-05-31    1996-06-30    1996-07-31  \
# count  1.086400e+04  1.088600e+04  1.096600e+04  1.099600e+04  1.102700e+04
# mean   1.215214e+05  1.215839e+05  1.217755e+05  1.218581e+05  1.220267e+05
# ...

# %%
home_prices_all.head()
# Out:
#    Unnamed: 0  RegionID  SizeRank   RegionName RegionType StateName State  \
# 0           0      6181         0     New York       City        NY    NY
# 1           1     12447         1  Los Angeles       City        CA    CA
# 2           2     39051         2      Houston       City        TX    TX
# 3           3     17426         3      Chicago       City        IL    IL
# 4           4      6915         4  San Antonio       City        TX    TX
#
#                               Metro          CountyName  1996-01-31  ...  \
# 0       New York-Newark-Jersey City       Queens County    196258.0  ...
# 1    Los Angeles-Long Beach-Anaheim  Los Angeles County    185649.0  ...
# 2  Houston-The Woodlands-Sugar Land       Harris County     93518.0  ...
# 3          Chicago-Naperville-Elgin         Cook County    130920.0  ...
# 4         San Antonio-New Braunfels        Bexar County     94041.0  ...
#
#    2019-06-30  2019-07-31  2019-08-31  2019-09-30  2019-10-31  2019-11-30  \
# ...

# %%
home_prices_all[home_prices_all.RegionName == 'Denver']
# Out:
#        Unnamed: 0  RegionID  SizeRank RegionName RegionType StateName State  \
# 23             23     11093        23     Denver       City        CO    CO
# 2816         2816     24367      2884     Denver       City        NC    NC
# 3895         3895     17755      4016     Denver       City        PA    PA
# 11635       11635     17754     12227     Denver       City        IA    IA
# 15577       15577     24366     16590     Denver       City        IN    IN
#
#                             Metro        CountyName  1996-01-31  ...  \
# 23         Denver-Aurora-Lakewood     Denver County    126922.0  ...
# 2816   Charlotte-Concord-Gastonia    Lincoln County    162273.0  ...
# 3895                    Lancaster  Lancaster County         NaN  ...
# 11635        Waterloo-Cedar Falls     Bremer County         NaN  ...
# 15577                        Peru      Miami County         NaN  ...
#
#        2019-06-30  2019-07-31  2019-08-31  2019-09-30  2019-10-31  2019-11-30  \
# ...

# %%
home_prices_county = home_prices_all['CountyName']

# %%
len(home_prices_all['State'].unique())
# Out:
# 51

# %%
county_rent = city_median_rent_all_homes['CountyName']

# %%
county_price = home_prices_all['CountyName']

# %%
type(county_rent)
# Out:
# pandas.core.series.Series

# %%
type(county_price)
# Out:
# pandas.core.series.Series

# %%
print(county_rent.keys())
# Out:
# RangeIndex(start=0, stop=1699, step=1)

# %%
print(county_price.keys())
# Out:
# RangeIndex(start=0, stop=27330, step=1)

# %%
print(county_rent.isin(county_price))
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#         ...
# 1694    True
# 1695    True
# 1696    True
# 1697    True
# 1698    True
# Name: CountyName, Length: 1699, dtype: bool

# %% [markdown]
# Confirming that all of the county values in the rental data set are in the house prices data set.

# %%
print(sorted(county_rent.isin(county_price)))
# Out:
# [True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, T
# ...

# %%
#establish uniqueness based on state and county pairing.
home_prices_all['state_county_for_joining'] = home_prices_all['State'] + ' ' + home_prices_all['CountyName']

# %%
home_prices_all.head()
# Out:
#    Unnamed: 0  RegionID  SizeRank   RegionName RegionType StateName State  \
# 0           0      6181         0     New York       City        NY    NY
# 1           1     12447         1  Los Angeles       City        CA    CA
# 2           2     39051         2      Houston       City        TX    TX
# 3           3     17426         3      Chicago       City        IL    IL
# 4           4      6915         4  San Antonio       City        TX    TX
#
#                               Metro          CountyName  1996-01-31  ...  \
# 0       New York-Newark-Jersey City       Queens County    196258.0  ...
# 1    Los Angeles-Long Beach-Anaheim  Los Angeles County    185649.0  ...
# 2  Houston-The Woodlands-Sugar Land       Harris County     93518.0  ...
# 3          Chicago-Naperville-Elgin         Cook County    130920.0  ...
# 4         San Antonio-New Braunfels        Bexar County     94041.0  ...
#
#    2019-07-31  2019-08-31  2019-09-30  2019-10-31  2019-11-30  2019-12-31  \
# ...

# %%
#create additional new column
city_median_rent_all_homes['state_county_for_joining'] = city_median_rent_all_homes['State'] + ' ' + city_median_rent_all_homes['CountyName']

# %%
city_median_rent_all_homes.head()
# Out:
#    Unnamed: 0   RegionName State                             Metro  \
# 0           0     New York    NY       New York-Newark-Jersey City
# 1           1  Los Angeles    CA    Los Angeles-Long Beach-Anaheim
# 2           2      Houston    TX  Houston-The Woodlands-Sugar Land
# 3           3      Chicago    IL          Chicago-Naperville-Elgin
# 4           4  San Antonio    TX         San Antonio-New Braunfels
#
#            CountyName  SizeRank  2010-01  2010-02  2010-03  2010-04  ...  \
# 0       Queens County         1      NaN      NaN      NaN      NaN  ...
# 1  Los Angeles County         2      NaN      NaN      NaN      NaN  ...
# 2       Harris County         3      NaN      NaN      NaN      NaN  ...
# 3         Cook County         4      NaN   1600.0   1500.0   1500.0  ...
# 4        Bexar County         5      NaN      NaN      NaN      NaN  ...
#
#    2019-04  2019-05  2019-06  2019-07  2019-08  2019-09  2019-10  2019-11  \
# ...

# %%
print(city_median_rent_all_homes['state_county_for_joining'].isin(home_prices_all['state_county_for_joining']))
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#         ...
# 1694    True
# 1695    True
# 1696    True
# 1697    True
# 1698    True
# Name: state_county_for_joining, Length: 1699, dtype: bool

# %%
#Are there duplicate county names in either df?
print(city_median_rent_all_homes['CountyName'].describe())
# Out:
# count                   1699
# unique                   492
# top       Los Angeles County
# freq                      47
# Name: CountyName, dtype: object

# %%
print(city_median_rent_all_homes.where(city_median_rent_all_homes['CountyName'] == 'Los Angeles County'))
# Out:
#       Unnamed: 0   RegionName State                           Metro  \
# 0            NaN          NaN   NaN                             NaN
# 1            1.0  Los Angeles    CA  Los Angeles-Long Beach-Anaheim
# 2            NaN          NaN   NaN                             NaN
# 3            NaN          NaN   NaN                             NaN
# 4            NaN          NaN   NaN                             NaN
# ...          ...          ...   ...                             ...
# 1694         NaN          NaN   NaN                             NaN
# 1695         NaN          NaN   NaN                             NaN
# 1696         NaN          NaN   NaN                             NaN
# 1697         NaN          NaN   NaN                             NaN
# 1698         NaN          NaN   NaN                             NaN
#
#               CountyName  SizeRank  2010-01  2010-02  2010-03  2010-04  ...  \
# ...

# %%
print(home_prices_all['CountyName'].describe())
# Out:
# count                 27330
# unique                 1753
# top       Washington County
# freq                    340
# Name: CountyName, dtype: object

# %%
print(len(city_median_rent_all_homes['CountyName'].unique()))
# Out:
# 492

# %%
print(home_prices_all['State'].unique())
# Out:
# ['NY' 'CA' 'TX' 'IL' 'PA' 'AZ' 'NV' 'FL' 'IN' 'NC' 'OH' 'KY' 'MI' 'CO'
#  'WA' 'TN' 'MA' 'DC' 'OR' 'MD' 'WI' 'NE' 'NM' 'OK' 'GA' 'MO' 'VA' 'MN'
#  'HI' 'LA' 'KS' 'SC' 'AK' 'NJ' 'AL' 'ID' 'IA' 'UT' 'AR' 'RI' 'SD' 'MS'
#  'CT' 'DE' 'MT' 'NH' 'ND' 'WY' 'WV' 'ME' 'VT']

# %%
print(city_median_rent_all_homes['State'].unique())
# Out:
# ['NY' 'CA' 'TX' 'IL' 'PA' 'AZ' 'NV' 'FL' 'IN' 'NC' 'OH' 'KY' 'MI' 'CO'
#  'WA' 'TN' 'MA' 'DC' 'OR' 'MD' 'WI' 'NE' 'NM' 'OK' 'GA' 'MO' 'VA' 'MN'
#  'HI' 'LA' 'KS' 'SC' 'AK' 'NJ' 'AL' 'ID' 'IA' 'UT' 'AR' 'RI' 'SD' 'MS'
#  'CT' 'DE' 'MT' 'NH' 'ND' 'WY' 'WV' 'ME']

# %% [markdown]
# Vermont is missing from the median rental data set.

# %%
len(city_median_rent_all_homes['State'].unique())
# Out:
# 50

# %%
home_prices_county.describe()
# Out:
# count        27330
# unique       17616
# top       Franklin
# freq            30
# Name: RegionName, dtype: object

# %%
len(home_prices_county)
# Out:
# 27330

# %%
home_prices_county.unique()
# Out:
# array(['Queens County', 'Los Angeles County', 'Harris County', ...,
#        'Thayer County', 'Chase County', 'Niobrara County'], dtype=object)

# %%
len(home_prices_county.unique())
# Out:
# 1753

# %%
home_prices_region = home_prices_all['RegionName']

# %%
len(home_prices_region.unique())
# Out:
# 17616

# %% [markdown]
# Looking at all regions with the name of Denver - there are 5 but no duplicates as these are all in different states.

# %%
#Count (using `.sum()`) the number of missing values (`.isnull()`) in each column of 
#home_prices as well as the percentages (using `.mean()` instead of `.sum()`).
#Order them (increasing or decreasing) using sort_values
#Call `pd.concat` to present these in a single table (DataFrame) with the helpful column names 'count' and '%'
missing = pd.concat([home_prices_region.isnull().sum(), 100 * home_prices_region.isnull().mean()], axis=1)
missing.columns=['count', '%']
missing.sort_values(by='count', ascending=False)
# Out:
#             count          %
# 1996-01-31  16713  61.152580
# 1996-02-29  16507  60.398829
# 1996-03-31  16466  60.248811
# 1996-04-30  16444  60.168313
# 1996-05-31  16364  59.875595
# ...           ...        ...
# 2018-05-31      0   0.000000
# 2018-06-30      0   0.000000
# 2018-07-31      0   0.000000
# 2018-08-31      0   0.000000
# 2020-03-31      0   0.000000
#
# [300 rows x 2 columns]

# %% [markdown]
# There is a large amount of null values... i think it would not be good to estimate the prices, so potentially dropping the months with 25% or more missing values?

# %%
home_prices_region.hist(bins=50)
# Out:
# array([[<AxesSubplot:title={'center':'Unnamed: 0'}>,
#         <AxesSubplot:title={'center':'RegionID'}>,
#         <AxesSubplot:title={'center':'SizeRank'}>,
#         <AxesSubplot:title={'center':'1996-01-31'}>,
#         <AxesSubplot:title={'center':'1996-02-29'}>,
#         <AxesSubplot:title={'center':'1996-03-31'}>,
#         <AxesSubplot:title={'center':'1996-04-30'}>,
#         <AxesSubplot:title={'center':'1996-05-31'}>,
#         <AxesSubplot:title={'center':'1996-06-30'}>,
#         <AxesSubplot:title={'center':'1996-07-31'}>,
#         <AxesSubplot:title={'center':'1996-08-31'}>,
#         <AxesSubplot:title={'center':'1996-09-30'}>,
#         <AxesSubplot:title={'center':'1996-10-31'}>,
#         <AxesSubplot:title={'center':'1996-11-30'}>,
#         <AxesSubplot:title={'center':'1996-12-31'}>,
#         <AxesSubplot:title={'center':'1997-01-31'}>,
#         <AxesSubplot:title={'center':'1997-02-28'}>],
#        [<AxesSubplot:title={'center':'1997-03-31'}>,
# ...

# %%
sns.histplot(data=missing, bins=50)
# Out:
# <AxesSubplot:ylabel='Count'>

# %%
dictionary_with_file_paths = {'../Zillow_housing_data_capstone1/DaysOnZillow_City.csv' : 'DaysOnZillow_City',
    '../Zillow_housing_data_capstone1/Sale_Prices_City.csv' : 'Sale_Prices_City',
    '../Zillow_housing_data_capstone1/City_MedianRentalPrice_Studio.csv' : 'City_MedianRentalPrice_Studio',
    '../Zillow_housing_data_capstone1/City_MedianRentalPrice_1Bedroom.csv' : 'City_MedianRentalPrice_1Bedroom',
    '../Zillow_housing_data_capstone1/City_MedianRentalPrice_2Bedroom.csv' : 'City_MedianRentalPrice_2Bedroom',
    '../Zillow_housing_data_capstone1/City_MedianRentalPrice_3Bedroom.csv' : 'City_MedianRentalPrice_3Bedroom',
    '../Zillow_housing_data_capstone1/City_MedianRentalPrice_4Bedroom.csv' : 'City_MedianRentalPrice_4Bedroom',
    '../Zillow_housing_data_capstone1/City_MedianRentalPrice_5BedroomOrMore.csv' : 'City_MedianRentalPrice_5BedroomOrMore',
    '../Zillow_housing_data_capstone1/City_Zhvi_1bedroom.csv' : 'City_Zhvi_1bedroom',
    '../Zillow_housing_data_capstone1/City_Zhvi_2bedroom.csv' : 'City_Zhvi_2bedroom',
    '../Zillow_housing_data_capstone1/City_Zhvi_3bedroom.csv' : 'City_Zhvi_3bedroom',
    '../Zillow_housing_data_capstone1/City_Zhvi_4bedroom.csv' : 'City_Zhvi_4bedroom',
    '../Zillow_housing_data_capstone1/City_Zhvi_5BedroomOrMore.csv' : 'City_Zhvi_5BedroomOrMore',
    '../Zillow_housing_data_capstone1/City_Zhvi_AllHomes.csv' : 'City_Zhvi_AllHomes',
    '../Zillow_housing_data_capstone1/City_Zhvi_SingleFamilyResidence.csv' : 'City_Zhvi_SingleFamilyResidence',
    '../Zillow_housing_data_capstone1/City_Zhvi_Condominum.csv' : 'City_Zhvi_Condominum',}
